# %% [markdown]
# Project setup: paths, output folders

# %%
from pathlib import Path

ROOT = Path(r"E:\S T A G E\Project")
CONFIGS = ROOT / "configs"
SCRAPERS = ROOT / "scrapers"
OUT = ROOT / "outputs"

for p in [CONFIGS, SCRAPERS, OUT]:
    p.mkdir(parents=True, exist_ok=True)

print("OK:", ROOT)
# Out:
# OK: E:\S T A G E\Project

# %%
import json, os
example_cfg = {
  "source_id": "SRC001",
  "start_urls": ["https://example.com"],
  "selectors": {
    "title": "h1",
    "body": "article",
    "date": "time",
    "author": ".author",
    "comments_block": "",
    "comment_author": "",
    "comment_date": "",
    "comment_body": ""
  },
  "pagination": {"enabled": False, "max_pages": 1},
  "dynamic": {"enabled": False, "wait_selector": None, "scroll_times": 0},
  "request": {"timeout_seconds": 30, "sleep_seconds_range": [1.0, 2.0], "max_retries": 3},
  "output": {"dir": "", "posts_jsonl": "posts.jsonl", "errors_jsonl": "errors.jsonl"}
}
print(json.dumps(example_cfg, indent=2))
# Out:
# {
#   "source_id": "SRC001",
#   "start_urls": [
#     "https://example.com"
#   ],
#   "selectors": {
#     "title": "h1",
#     "body": "article",
#     "date": "time",
#     "author": ".author",
#     "comments_block": "",
#     "comment_author": "",
#     "comment_date": "",
#     "comment_body": ""
#   },
#   "pagination": {
#     "enabled": false,
#     "max_pages": 1
#   },
#   "dynamic": {
#     "enabled": false,
#     "wait_selector": null,
#     "scroll_times": 0
#   },
#   "request": {
#     "timeout_seconds": 30,
#     "sleep_seconds_range": [
#       1.0,
#       2.0
#     ],
#     "max_retries": 3
#   },
#   "output": {
#     "dir": "",
#     "posts_jsonl": "posts.jsonl",
#     "errors_jsonl": "errors.jsonl"
#   }
# }
